# %% [markdown]
# # **Разметка текстов**
# ### **1.** Использование одной из библиотек (nltk , mystem , pymorphy) для разметки частей речи и измерения качества для нескольких текстов из размеченных корпусов для русского языка.
#
# ### **2.** Разметка частей речи и именованных сущностей, анализ ошибок алгоритма для нескольких текстов новостного датасета.

# %%
import os
import spacy
from spacy import displacy
import pandas as pd
import opencorpora
import numpy as np
import lxml
from lxml import objectify, etree, html
from xml.etree import ElementTree as xml
import urllib3
from io import StringIO, BytesIO
import re
import codecs
from pymystem3 import Mystem
import copy
import nltk
import string
import sklearn
import scipy
import itertools
import json
import random
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Часть 1
# **Выбрать несколько текстов из размеченных корпусов для русского языка. Использовать одну
# из библиотек ( nltk , mystem , pymorphy ) для разметки частей речи, измерить качество.**

# %% [markdown]
# В качестве данных был взят корпус **OpenCorpora.org**

# %% [markdown]
# ## Чтение и подготовка данных

# %%
corpus = opencorpora.load('annot.opcorpora.xml')

# %% [markdown]
# Сначала я учусь вытаскивать разную информацию из корпуса.

# %%
len(corpus.docs)
# Out:
# 4030

# %%
len(corpus.sentences)
# Out:
# 110306

# %% [markdown]
# В данном размеченном корпусе содержится 110 306 предложений.

# %%
corpus.sentences[17]
# Out:
# <Sentence id=18 source='Это произошло году в 2005-м, когда на смену героям, кочующим из одного ток-шоу в другое и по дороге заглядывающим в «Школу злословия», к Татьяне Никитичне и Авдотье Андреевне стал приходить совсем другой народ: политологи, публицисты, причем практически исключительно либеральных убеждений.'>

# %%
doc = corpus[42]
doc
# Out:
# <Doc id=44 tokens:2502 name='18801 Хитрость духа'>

# %%
doc.source
# Out:
# 'Хитрость духа  Почему князь Владимир крестил Русь\n\n28 июля православная церковь чтит память равноапостольного князя Владимира, в крещении Василия.  В этом году впервые на государственном уровне празднуют этот день как День Крещения Руси.  Крестившись сам, Владимир затем крестил своих поданных, отсюда пошла русская православная цивилизация.  В том числе и ее проблемы, возможно, связанные с некоторыми свойствами характера Владимира Святославича, прозванного в былинах Красно Солнышко.\n\nУ князя Святослава Игоревича было три сына: Ярополк, Олег и Владимир.  Имена матерей первых двух неизвестны, а Владимира родила Малуша, которая была рабыней, ключницей матери Святослава Ольги (см. здесь ).  В «Повести временных лет» сказано, что Малуша «была сестра Добрыни, а отец им был Малк Любечанин».  Кто такой — неизвестно, возможно, тот самый древлянин Мал, которой убил князя Игоря и которому Ольга мстила.  Если так, то Малуша была пленной древлянкой.  Но как бы там ни было, девушка была хороша собой, и забуревший в вечных походах Святослав не выдержал.  Обнаружив, что ключница забеременела, Ольга разгневалась и отослала её в село Будутино под Псковом, где и родился Владимир.  Точно неизвестно, когда именно это случилось, но историки условились считать, что примерно в 960 году.\n\nВоспитывал Владимира его дядя Добрыня (который потом превратится в былинного богатыря Добрыню Никитича и в этом качестве станет уже племянником Владимира).  Исторический Добрыня — фигура довольно зловещая, возможно, именно в его голове созрели замыслы некоторых из тех страшных деяний Владимира, которые описаны в летописях.\n\nНо пойдём по порядку.  Святослав посадил Ярополка в Киеве, а Олега у древлян.  Незаконнорождённому же сыну он не дал никакого удела.  Однако когда 970 году новгородцы стали требовать себе князя («Если не пойдёте к нам, то сами добудем себе князя»), а Ярополк и Олег отказались от такой чести, Добрыня сказал: «Просите Владимира».  Те попросили, и Святослав сказал: «Вот он вам».  Мальчику в это время было лет десять, так что князем в Новгороде фактически стал Добрыня.\n\nВладимир не мог надеться на Киевский стол, пока были живы его братья Ярополк и Олег.  Но вскоре после гибели Святослава (972) они поссорились.  Причиной, как говорит «Повесть временных лет», стало то, что Олег убил на охоте сына воеводы Свенельда, того самого, что служил ещё Игорю, потом Ольге и Святославу.  Свенельд был человеком очень влиятельным.  Он и заставил Ярополка начать войну с братом.  Олег был разбит под Овручем, бежал в город, но в панике отступления упал с моста в ров и оказался раздавлен телами других беглецов.  Ярополк ужасно переживал, узнав о его гибели, он совсем не хотел смерти брата.\n\nМежду тем Владимир почему-то решил, что Ярополк теперь обязательно доберётся и до него.  И потому бежал вместе с дядей Добрыней за море.  Вернулся в 980 году с наёмной варяжской дружиной.  Для укрепления своего положения решил жениться на Полоцкой княжне Рогнеде.  Послал её отцу князю Рогволоду предложение.  Княжна ответила: не хочу робичича, хочу Ярополка.  Это было чувствительное оскорбление.  Добрыня особенно был уязвлён тем, что его сестру называют рабыней.  И вот результат: «И напал Владимир на Полоцк, и убил Рогволода и двух его сыновей, а дочь его взял в жены».  Вообще-то в оригинале написано «поя жене», что означает немного другое...  Существует даже предание, что Владимир изнасиловал гордячку прямо на глазах своих варяжских головорезов.\n\nПосле падения Полоцка настала очередь Киева.  Когда войска Владимира подошли к городу, Ярополк повёл себя глупо и нерешительно.  Может быть, его надломила нечаянная смерть Олега, а может — разлагающее влияние греческих попов, которых привечала его бабка Ольга (иногда говорят, что он и сам был христианином).  Как бы то ни было, вместо того чтобы сражаться, Ярополк решил отсидеться за стенами Киева.  Хуже всего то, что он слишком доверял своему воеводе, носившему говорящее имя Блуд.  Этот Блуд вступил в переговоры с Владимиром, со ...

# %%
len(doc.sentences)
# Out:
# 160

# %%
doc.tokens
# Out:
# [<Token id=64838 source='Хитрость'>,
#  <Token id=64839 source='духа'>,
#  <Token id=64840 source='Почему'>,
#  <Token id=64841 source='князь'>,
#  <Token id=64842 source='Владимир'>,
#  <Token id=64843 source='крестил'>,
#  <Token id=64844 source='Русь'>,
#  <Token id=64845 source='28'>,
#  <Token id=64846 source='июля'>,
#  <Token id=64847 source='православная'>,
#  <Token id=64848 source='церковь'>,
#  <Token id=64849 source='чтит'>,
#  <Token id=64850 source='память'>,
#  <Token id=64851 source='равноапостольного'>,
#  <Token id=64852 source='князя'>,
#  <Token id=64853 source='Владимира'>,
#  <Token id=64854 source=','>,
#  <Token id=64855 source='в'>,
#  <Token id=64856 source='крещении'>,
#  <Token id=64857 source='Василия'>,
#  <Token id=64858 source='.'>,
#  <Token id=64859 source='В'>,
#  <Token id=64860 source='этом'>,
#  <Token id=64861 source='году'>,
#  <Token id=64862 source='впервые'>,
#  <Token id=64863 source='на'>,
#  <Token id=64864 source='государственном'>,
#  <Token id=64865 source='уровне'>,
#  <Token id=64866 source='празднуют'>,
#  <Token id=64867 source='этот'>,
#  <Token id=64868 source='день'>,
#  <Token id=64869 source='как'>,
#  <Token id=64870 source='День'>,
#  <Token id=64871 source='Крещения'>,
#  <Token id=64872 source='Руси'>,
#  <Token id=64873 source='.'>,
#  <Token id=64874 source='Крестившись'>,
#  <Token id=64875 source='сам'>,
#  <Token id=64876 source=','>,
#  <Token id=64877 source='Владимир'>,
#  <Token id=64878 source='затем'>,
#  <Token id=64879 source='крестил'>,
#  <Token id=64880 source='своих'>,
#  <Token id=64881 source='поданных'>,
#  <Token id=64882 source=','>,
#  <Token id=64883 source='отсюда'>,
#  <Token id=64884 source='пошла'>,
#  <Token id=64885 source='русская'>,
#  <Token id=64886 source='православная'>,
#  <Token id=64887 source='цивилизация'>,
#  <Token id=64888 source='.'>,
#  <Token id=64889 source='В'>,
#  <Token id=64890 source='том'>,
#  <Token id=64891 source='числе'>,
#  <Token id=64892 source='и'>,
#  <Token id=64893 source='ее'>,
#  <Token id=64894 source='проблемы'>,
#  <Token id=64895 source=','>,
#  <Token id=64896 source='возможно'>,
#  <Token id=64897 source=','>,
#  <Token id=64898 source='связанные'>,
#  <Token id=64899 source='с'>,
#  <Token id=64900 source='некоторыми'>,
#  <Token id=64901 source='свойствами'>,
#  <Token id=64902 source='характера'>,
#  <Token id=64903 source='Владимира'>,
#  <Token id=64904 source='Святославича'>,
#  <Token id=64905 source=','>,
#  <Token id=64906 source='прозванного'>,
#  <Token id=64907 source='в'>,
#  <Token id=64908 source='былинах'>,
#  <Token id=64909 source='Красно'>,
#  <Token id=64910 source='Солнышко'>,
#  <Token id=64911 source='.'>,
#  <Token id=64912 source='У'>,
#  <Token id=64913 source='князя'>,
#  <Token id=64914 source='Святослава'>,
#  <Token id=64915 source='Игоревича'>,
#  <Token id=64916 source='было'>,
#  <Token id=64917 source='три'>,
#  <Token id=64918 source='сына'>,
#  <Token id=64919 source=':'>,
#  <Token id=64920 source='Ярополк'>,
#  <Token id=64921 source=','>,
#  <Token id=64922 source='Олег'>,
#  <Token id=64923 source='и'>,
#  <Token id=64924 source='Владимир'>,
#  <Token id=64925 source='.'>,
#  <Token id=64926 source='Имена'>,
#  <Token id=64927 source='матерей'>,
#  <Token id=64928 source='первых'>,
#  <Token id=64929 source='двух'>,
#  <Token id=64930 source='неизвестны'>,
#  <Token id=64931 source=','>,
#  <Token id=64932 source='а'>,
#  <Token id=64933 source='Владимира'>,
#  <Token id=64934 source='родила'>,
#  <Token id=64935 source='Малуша'>,
#  <Token id=64936 source=','>,
#  <Token id=64937 source='которая'>,
#  <Token id=64938 source='была'>,
#  <Token id=64939 source='рабыней'>,
#  <Token id=64940 source=','>,
#  <Token id=64941 source='ключницей'>,
#  <Token id=64942 source='матери'>,
#  <Token id=64943 source='Святослава'>,
#  <Token id=64944 source='Ольги'>,
#  <Token id=64945 source='('>,
#  <Token id=64946 source='см'>,
#  <Token id=64947 source='.'>,
#  <Token id=64948 source='здесь'>,
#  <Token id=64949 source=')'>,
#  <Token id=64950 source='.'>,
#  <Token id=64951 source='В'>,
#  <Token id=64952 source='«'>,
#  <Token id=64953 source='Повести'>,
#  <Token id=64954 source='временных'>,
#  <Token id=64955 source='лет'>,
#  <Token id=64956 source='»'>,
#  <Token id=64957 source='сказано'>,
#  <Token id=64958 source=','>,
#  <Token id=64959 source='что'>,
#  <Token id=64960 source='Малуша'>,
#  <Token id=64961 source='«'>,
#  <Token id=64962 source='была'>,
#  <Token id=64963 source='сестра'>,
#  <Token id=64964 source='Добрыни'>,
#  <Token id=64965 source=','>,
#  <Token id=64966 source='а'>,
#  <Token id=64967 source='отец'>,
#  <Token id=64968 source='им'>,
#  <Token id=64969 source='был'>,
#  <Token id=64970 source='Малк'>,
#  <Token id=64971 source='Любечанин'>,
#  <Token id=64972 source='»'>,
#  <Token id=64973 source='.'>,
#  <Token id=64974 source='Кто'>,
#  <Token id=64975 source='такой'>,
#  <Token id=64976 source='—'>,
#  <Token id=64977 source='неизвестно'>,
#  <Token id=64978 source=','>,
#  <Token id=64979 source='возможно'>,
#  <Token id=64980 source=','>,
#  <Token id=64981 source='тот'>,
#  <Token id=64982 source='самый'>,
#  <Token id=64983 source='древлянин'>,
#  <Token id=64984 source='Мал'>,
#  <Token id=64985 source=','>,
#  <Token id=64986 source='которой'>,
#  <Token id=64987 source='убил'>,
#  <Token id=64988 source='князя'>,
#  <Token id=64989 source='Игоря'>,
#  <Token id=64990 source='и'>,
#  <Token id=64991 source='которому'>,
#  <Token id=64992 source='Ольга'>,
#  <Token id=64993 source='мстила'>,
#  <Token id=64994 source='.'>,
#  <Token id=64995 source='Если'>,
#  <Token id=64996 source='так'>,
#  <Token id=64997 source=','>,
#  <Token id=64998 source='то'>,
#  <Token id=64999 source='Малуша'>,
#  <Token id=65000 source='была'>,
#  <Token id=65001 source='пленной'>,
#  <Token id=65002 source='древлянкой'>,
#  <Token id=65003 source='.'>,
#  <Token id=65004 source='Но'>,
#  <Token id=65005 source='как'>,
#  <Token id=65006 source='бы'>,
#  <Token id=65007 source='там'>,
#  <Token id=65008 source='ни'>,
#  <Token id=65009 source='было'>,
#  <Token id=65010 source=','>,
#  <Token id=65011 source='девушка'>,
#  <Token id=65012 source='была'>,
#  <Token id=65013 source='хороша'>,
#  <Token id=65014 source='собой'>,
#  <Token id=65015 source=','>,
#  <Token id=65016 source='и'>,
#  <Token id=65017 source='забуревший'>,
#  <Token id=65018 source='в'>,
#  <Token id=65019 source='вечных'>,
#  <Token id=65020 source='походах'>,
#  <Token id=65021 source='Святослав'>,
#  <Token id=65022 source='не'>,
#  <Token id=65023 source='выдержал'>,
#  <Token id=65024 source='.'>,
#  <Token id=65025 source='Обнаружив'>,
#  <Token id=65026 source=','>,
#  <Token id=65027 source='что'>,
#  <Token id=65028 source='ключница'>,
#  <Token id=65029 source='забеременела'>,
#  <Token id=65030 source=','>,
#  <Token id=65031 source='Ольга'>,
#  <Token id=65032 source='разгневалась'>,
#  <Token id=65033 source='и'>,
#  <Token id=65034 source='отослала'>,
#  <Token id=65035 source='её'>,
#  <Token id=65036 source='в'>,
#  <Token id=65037 source='село'>,
#  <Token id=65038 source='Будутино'>,
#  <Token id=65039 source='под'>,
#  <Token id=65040 source='Псковом'>,
#  <Token id=65041 source=','>,
#  <Token id=65042 source='где'>,
#  <Token id=65043 source='и'>,
#  <Token id=65044 source='родился'>,
#  <Token id=65045 source='Владимир'>,
#  <Token id=65046 source='.'>,
#  <Token id=65047 source='Точно'>,
#  <Token id=65048 source='неизвестно'>,
#  <Token id=65049 source=','>,
#  <Token id=65050 source='когда'>,
#  <Token id=65051 source='именно'>,
#  <Token id=65052 source='это'>,
#  <Token id=65053 source='случилось'>,
#  <Token id=65054 source=','>,
#  <Token id=65055 source='но'>,
#  <Token id=65056 source='историки'>,
#  <Token id=65057 source='условились'>,
#  <Token id=65058 source='считать'>,
#  <Token id=65059 source=','>,
#  <Token id=65060 source='что'>,
#  <Token id=65061 source='примерно'>,
#  <Token id=65062 source='в'>,
#  <Token id=65063 source='960'>,
#  <Token id=65064 source='году'>,
#  <Token id=65065 source='.'>,
#  <Token id=65066 source='Воспитывал'>,
#  <Token id=65067 source='Владимира'>,
#  <Token id=65068 source='его'>,
#  <Token id=65069 source='дядя'>,
#  <Token id=65070 source='Добрыня'>,
#  <Token id=65071 source='('>,
#  <Token id=65072 source='который'>,
#  <Token id=65073 source='потом'>,
#  <Token id=65074 source='превратится'>,
#  <Token id=65075 source='в'>,
#  <Token id=65076 source='былинного'>,
#  <Token id=65077 source='богатыря'>,
#  <Token id=65078 source='Добрыню'>,
#  <Token id=65079 source='Никитича'>,
#  <Token id=65080 source='и'>,
#  <Token id=65081 source='в'>,
#  <Token id=65082 source='этом'>,
#  <Token id=65083 source='качестве'>,
#  <Token id=65084 source='станет'>,
#  <Token id=65085 source='уже'>,
#  <Token id=65086 source='племянником'>,
#  <Token id=65087 source='Владимира'>,
#  <Token id=65088 source=')'>,
#  <Token id=65089 source='.'>,
#  <Token id=65090 source='Исторический'>,
#  <Token id=65091 source='Добрыня'>,
#  <Token id=65092 source='—'>,
#  <Token id=65093 source='фигура'>,
#  <Token id=65094 source='довольно'>,
#  <Token id=65095 source='зловещая'>,
#  <Token id=65096 source=','>,
#  <Token id=65097 source='возможно'>,
#  <Token id=65098 source=','>,
#  <Token id=65099 source='именно'>,
#  <Token id=65100 source='в'>,
#  <Token id=65101 source='его'>,
#  <Token id=65102 source='голове'>,
#  <Token id=65103 source='созрели'>,
#  <Token id=65104 source='замыслы'>,
#  <Token id=65105 source='некоторых'>,
#  <Token id=65106 source='из'>,
#  <Token id=65107 source='тех'>,
#  <Token id=65108 source='страшных'>,
#  <Token id=65109 source='деяний'>,
#  <Token id=65110 source='Владимира'>,
#  <Token id=65111 source=','>,
#  <Token id=65112 source='которые'>,
#  <Token id=65113 source='описаны'>,
#  <Token id=65114 source='в'>,
#  <Token id=65115 source='летописях'>,
#  <Token id=65116 source='.'>,
#  <Token id=65117 source='Но'>,
#  <Token id=65118 source='пойдём'>,
#  <Token id=65119 source='по'>,
#  <Token id=65120 source='порядку'>,
#  <Token id=65121 source='.'>,
#  <Token id=65122 source='Святослав'>,
#  <Token id=65123 source='посадил'>,
#  <Token id=65124 source='Ярополка'>,
#  <Token id=65125 source='в'>,
#  <Token id=65126 source='Киеве'>,
#  <Token id=65127 source=','>,
#  <Token id=65128 source='а'>,
#  <Token id=65129 source='Олега'>,
#  <Token id=65130 source='у'>,
#  <Token id=65131 source='древлян'>,
#  <Token id=65132 source='.'>,
#  <Token id=65133 source='Незаконнорождённому'>,
#  <Token id=65134 source='же'>,
#  <Token id=65135 source='сыну'>,
#  <Token id=65136 source='он'>,
#  <Token id=65137 source='не'>,
#  <Token id=65138 source='дал'>,
#  <Token id=65139 source='никакого'>,
#  <Token id=65140 source='удела'>,
#  <Token id=65141 source='.'>,
#  <Token id=65142 source='Однако'>,
#  <Token id=65143 source='когда'>,
#  <Token id=65144 source='970'>,
#  <Token id=65145 source='году'>,
#  <Token id=65146 source='новгородцы'>,
#  <Token id=65147 source='стали'>,
#  <Token id=65148 source='требовать'>,
#  <Token id=65149 source='себе'>,
#  <Token id=65150 source='князя'>,
#  <Token id=65151 source='('>,
#  <Token id=65152 source='«'>,
#  <Token id=65153 source='Если'>,
#  <Token id=65154 source='не'>,
#  <Token id=65155 source='пойдёте'>,
#  <Token id=65156 source='к'>,
#  <Token id=65157 source='нам'>,
#  <Token id=65158 source=','>,
#  <Token id=65159 source='то'>,
#  <Token id=65160 source='сами'>,
#  <Token id=65161 source='добудем'>,
#  <Token id=65162 source='себе'>,
#  <Token id=65163 source='князя'>,
#  <Token id=65164 source='»'>,
#  <Token id=65165 source=')'>,
#  <Token id=65166 source=','>,
#  <Token id=65167 source='а'>,
#  <Token id=65168 source='Ярополк'>,
#  <Token id=65169 source='и'>,
#  <Token id=65170 source='Олег'>,
#  <Token id=65171 source='отказались'>,
#  <Token id=65172 source='от'>,
#  <Token id=65173 source='такой'>,
#  <Token id=65174 source='чести'>,
#  <Token id=65175 source=','>,
#  <Token id=65176 source='Добрыня'>,
#  <Token id=65177 source='сказал'>,
#  <Token id=65178 source=':'>,
#  <Token id=65179 source='«'>,
#  <Token id=65180 source='Просите'>,
#  <Token id=65181 source='Владимира'>,
#  <Token id=65182 source='»'>,
#  <Token id=65183 source='.'>,
#  <Token id=65184 source='Те'>,
#  <Token id=65185 source='попросили'>,
#  <Token id=65186 source=','>,
#  <Token id=65187 source='и'>,
#  <Token id=65188 source='Святослав'>,
#  <Token id=65189 source='сказал'>,
#  <Token id=65190 source=':'>,
#  <Token id=65191 source='«'>,
#  <Token id=65192 source='Вот'>,
#  <Token id=65193 source='он'>,
#  <Token id=65194 source='вам'>,
#  <Token id=65195 source='»'>,
#  <Token id=65196 source='.'>,
#  <Token id=65197 source='Мальчику'>,
#  <Token id=65198 source='в'>,
#  <Token id=65199 source='это'>,
#  <Token id=65200 source='время'>,
#  <Token id=65201 source='было'>,
#  <Token id=65202 source='лет'>,
#  <Token id=65203 source='десять'>,
#  <Token id=65204 source=','>,
#  <Token id=65205 source='так'>,
#  <Token id=65206 source='что'>,
#  <Token id=65207 source='князем'>,
#  <Token id=65208 source='в'>,
#  <Token id=65209 source='Новгороде'>,
#  <Token id=65210 source='фактически'>,
#  <Token id=65211 source='стал'>,
#  <Token id=65212 source='Добрыня'>,
#  <Token id=65213 source='.'>,
#  <Token id=65214 source='Владимир'>,
#  <Token id=65215 source='не'>,
#  <Token id=65216 source='мог'>,
#  <Token id=65217 source='надеться'>,
#  <Token id=65218 source='на'>,
#  <Token id=65219 source='Киевский'>,
#  <Token id=65220 source='стол'>,
#  <Token id=65221 source=','>,
#  <Token id=65222 source='пока'>,
#  <Token id=65223 source='были'>,
#  <Token id=65224 source='живы'>,
#  <Token id=65225 source='его'>,
#  <Token id=65226 source='братья'>,
#  <Token id=65227 source='Ярополк'>,
#  <Token id=65228 source='и'>,
#  <Token id=65229 source='Олег'>,
#  <Token id=65230 source='.'>,
#  <Token id=65231 source='Но'>,
#  <Token id=65232 source='вскоре'>,
#  <Token id=65233 source='после'>,
#  <Token id=65234 source='гибели'>,
#  <Token id=65235 source='Святослава'>,
#  <Token id=65236 source='('>,
#  <Token id=65237 source='972'>,
#  <Token id=65238 source=')'>,
#  <Token id=65239 source='они'>,
#  <Token id=65240 source='поссорились'>,
#  <Token id=65241 source='.'>,
#  <Token id=65242 source='Причиной'>,
#  <Token id=65243 source=','>,
#  <Token id=65244 source='как'>,
#  <Token id=65245 source='говорит'>,
#  <Token id=65246 source='«'>,
#  <Token id=65247 source='Повесть'>,
#  <Token id=65248 source='временных'>,
#  <Token id=65249 source='лет'>,
#  <Token id=65250 source='»'>,
#  <Token id=65251 source=','>,
#  <Token id=65252 source='стало'>,
#  <Token id=65253 source='то'>,
#  <Token id=65254 source=','>,
#  <Token id=65255 source='что'>,
#  <Token id=65256 source='Олег'>,
#  <Token id=65257 source='убил'>,
#  <Token id=65258 source='на'>,
#  <Token id=65259 source='охоте'>,
#  <Token id=65260 source='сына'>,
#  <Token id=65261 source='воеводы'>,
#  <Token id=65262 source='Свенельда'>,
#  <Token id=65263 source=','>,
#  <Token id=65264 source='того'>,
#  <Token id=65265 source='самого'>,
#  <Token id=65266 source=','>,
#  <Token id=65267 source='что'>,
#  <Token id=65268 source='служил'>,
#  <Token id=65269 source='ещё'>,
#  <Token id=65270 source='Игорю'>,
#  <Token id=65271 source=','>,
#  <Token id=65272 source='потом'>,
#  <Token id=65273 source='Ольге'>,
#  <Token id=65274 source='и'>,
#  <Token id=65275 source='Святославу'>,
#  <Token id=65276 source='.'>,
#  <Token id=65277 source='Свенельд'>,
#  <Token id=65278 source='был'>,
#  <Token id=65279 source='человеком'>,
#  <Token id=65280 source='очень'>,
#  <Token id=65281 source='влиятельным'>,
#  <Token id=65282 source='.'>,
#  <Token id=65283 source='Он'>,
#  <Token id=65284 source='и'>,
#  <Token id=65285 source='заставил'>,
#  <Token id=65286 source='Ярополка'>,
#  <Token id=65287 source='начать'>,
#  <Token id=65288 source='войну'>,
#  <Token id=65289 source='с'>,
#  <Token id=65290 source='братом'>,
#  <Token id=65291 source='.'>,
#  <Token id=65292 source='Олег'>,
#  <Token id=65293 source='был'>,
#  <Token id=65294 source='разбит'>,
#  <Token id=65295 source='под'>,
#  <Token id=65296 source='Овручем'>,
#  <Token id=65297 source=','>,
#  <Token id=65298 source='бежал'>,
#  <Token id=65299 source='в'>,
#  <Token id=65300 source='город'>,
#  <Token id=65301 source=','>,
#  <Token id=65302 source='но'>,
#  <Token id=65303 source='в'>,
#  <Token id=65304 source='панике'>,
#  <Token id=65305 source='отступления'>,
#  <Token id=65306 source='упал'>,
#  <Token id=65307 source='с'>,
#  <Token id=65308 source='моста'>,
#  <Token id=65309 source='в'>,
#  <Token id=65310 source='ров'>,
#  <Token id=65311 source='и'>,
#  <Token id=65312 source='оказался'>,
#  <Token id=65313 source='раздавлен'>,
#  <Token id=65314 source='телами'>,
#  <Token id=65315 source='других'>,
#  <Token id=65316 source='беглецов'>,
#  <Token id=65317 source='.'>,
#  <Token id=65318 source='Ярополк'>,
#  <Token id=65319 source='ужасно'>,
#  <Token id=65320 source='переживал'>,
#  <Token id=65321 source=','>,
#  <Token id=65322 source='узнав'>,
#  <Token id=65323 source='о'>,
#  <Token id=65324 source='его'>,
#  <Token id=65325 source='гибели'>,
#  <Token id=65326 source=','>,
#  <Token id=65327 source='он'>,
#  <Token id=65328 source='совсем'>,
#  <Token id=65329 source='не'>,
#  <Token id=65330 source='хотел'>,
#  <Token id=65331 source='смерти'>,
#  <Token id=65332 source='брата'>,
#  <Token id=65333 source='.'>,
#  <Token id=65334 source='Между'>,
#  <Token id=65335 source='тем'>,
#  <Token id=65336 source='Владимир'>,
#  <Token id=65337 source='почему-то'>,
#  <Token id=65338 source='решил'>,
#  <Token id=65339 source=','>,
#  <Token id=65340 source='что'>,
#  <Token id=65341 source='Ярополк'>,
#  <Token id=65342 source='теперь'>,
#  <Token id=65343 source='обязательно'>,
#  <Token id=65344 source='доберётся'>,
#  <Token id=65345 source='и'>,
#  <Token id=65346 source='до'>,
#  <Token id=65347 source='него'>,
#  <Token id=65348 source='.'>,
#  <Token id=65349 source='И'>,
#  <Token id=65350 source='потому'>,
#  <Token id=65351 source='бежал'>,
#  <Token id=65352 source='вместе'>,
#  <Token id=65353 source='с'>,
#  <Token id=65354 source='дядей'>,
#  <Token id=65355 source='Добрыней'>,
#  <Token id=65356 source='за'>,
#  <Token id=65357 source='море'>,
#  <Token id=65358 source='.'>,
#  <Token id=65359 source='Вернулся'>,
#  <Token id=65360 source='в'>,
#  <Token id=65361 source='980'>,
#  <Token id=65362 source='году'>,
#  <Token id=65363 source='с'>,
#  <Token id=65364 source='наёмной'>,
#  <Token id=65365 source='варяжской'>,
#  <Token id=65366 source='дружиной'>,
#  <Token id=65367 source='.'>,
#  <Token id=65368 source='Для'>,
#  <Token id=65369 source='укрепления'>,
#  <Token id=65370 source='своего'>,
#  <Token id=65371 source='положения'>,
#  <Token id=65372 source='решил'>,
#  <Token id=65373 source='жениться'>,
#  <Token id=65374 source='на'>,
#  <Token id=65375 source='Полоцкой'>,
#  <Token id=65376 source='княжне'>,
#  <Token id=65377 source='Рогнеде'>,
#  <Token id=65378 source='.'>,
#  <Token id=65379 source='Послал'>,
#  <Token id=65380 source='её'>,
#  <Token id=65381 source='отцу'>,
#  <Token id=65382 source='князю'>,
#  <Token id=65383 source='Рогволоду'>,
#  <Token id=65384 source='предложение'>,
#  <Token id=65385 source='.'>,
#  <Token id=65386 source='Княжна'>,
#  <Token id=65387 source='ответила'>,
#  <Token id=65388 source=':'>,
#  <Token id=65389 source='не'>,
#  <Token id=65390 source='хочу'>,
#  <Token id=65391 source='робичича'>,
#  <Token id=65392 source=','>,
#  <Token id=65393 source='хочу'>,
#  <Token id=65394 source='Ярополка'>,
#  <Token id=65395 source='.'>,
#  <Token id=65396 source='Это'>,
#  <Token id=65397 source='было'>,
#  <Token id=65398 source='чувствительное'>,
#  <Token id=65399 source='оскорбление'>,
#  <Token id=65400 source='.'>,
#  <Token id=65401 source='Добрыня'>,
#  <Token id=65402 source='особенно'>,
#  <Token id=65403 source='был'>,
#  <Token id=65404 source='уязвлён'>,
#  <Token id=65405 source='тем'>,
#  <Token id=65406 source=','>,
#  <Token id=65407 source='что'>,
#  <Token id=65408 source='его'>,
#  <Token id=65409 source='сестру'>,
#  <Token id=65410 source='называют'>,
#  <Token id=65411 source='рабыней'>,
#  <Token id=65412 source='.'>,
#  <Token id=65413 source='И'>,
#  <Token id=65414 source='вот'>,
#  <Token id=65415 source='результат'>,
#  <Token id=65416 source=':'>,
#  <Token id=65417 source='«'>,
#  <Token id=65418 source='И'>,
#  <Token id=65419 source='напал'>,
#  <Token id=65420 source='Владимир'>,
#  <Token id=65421 source='на'>,
#  <Token id=65422 source='Полоцк'>,
#  <Token id=65423 source=','>,
#  <Token id=65424 source='и'>,
#  <Token id=65425 source='убил'>,
#  <Token id=65426 source='Рогволода'>,
#  <Token id=65427 source='и'>,
#  <Token id=65428 source='двух'>,
#  <Token id=65429 source='его'>,
#  <Token id=65430 source='сыновей'>,
#  <Token id=65431 source=','>,
#  <Token id=65432 source='а'>,
#  <Token id=65433 source='дочь'>,
#  <Token id=65434 source='его'>,
#  <Token id=65435 source='взял'>,
#  <Token id=65436 source='в'>,
#  <Token id=65437 source='жены'>,
#  <Token id=65438 source='»'>,
#  <Token id=65439 source='.'>,
#  <Token id=65440 source='Вообще-то'>,
#  <Token id=65441 source='в'>,
#  <Token id=65442 source='оригинале'>,
#  <Token id=65443 source='написано'>,
#  <Token id=65444 source='«'>,
#  <Token id=65445 source='поя'>,
#  <Token id=65446 source='жене'>,
#  <Token id=65447 source='»'>,
#  <Token id=65448 source=','>,
#  <Token id=65449 source='что'>,
#  <Token id=65450 source='означает'>,
#  <Token id=65451 source='немного'>,
#  <Token id=65452 source='другое'>,
#  <Token id=65453 source='...'>,
#  <Token id=65454 source='Существует'>,
#  <Token id=65455 source='даже'>,
#  <Token id=65456 source='предание'>,
#  <Token id=65457 source=','>,
#  <Token id=65458 source='что'>,
#  <Token id=65459 source='Владимир'>,
#  <Token id=65460 source='изнасиловал'>,
#  <Token id=65461 source='гордячку'>,
#  <Token id=65462 source='прямо'>,
#  <Token id=65463 source='на'>,
#  <Token id=65464 source='глазах'>,
#  <Token id=65465 source='своих'>,
#  <Token id=65466 source='варяжских'>,
#  <Token id=65467 source='головорезов'>,
#  <Token id=65468 source='.'>,
#  <Token id=65469 source='После'>,
#  <Token id=65470 source='падения'>,
#  <Token id=65471 source='Полоцка'>,
#  <Token id=65472 source='настала'>,
#  <Token id=65473 source='очередь'>,
#  <Token id=65474 source='Киева'>,
#  <Token id=65475 source='.'>,
#  <Token id=65476 source='Когда'>,
#  <Token id=65477 source='войска'>,
#  <Token id=65478 source='Владимира'>,
#  <Token id=65479 source='подошли'>,
#  <Token id=65480 source='к'>,
#  <Token id=65481 source='городу'>,
#  <Token id=65482 source=','>,
#  <Token id=65483 source='Ярополк'>,
#  <Token id=65484 source='повёл'>,
#  <Token id=65485 source='себя'>,
#  <Token id=65486 source='глупо'>,
#  <Token id=65487 source='и'>,
#  <Token id=65488 source='нерешительно'>,
#  <Token id=65489 source='.'>,
#  <Token id=65490 source='Может'>,
#  <Token id=65491 source='быть'>,
#  <Token id=65492 source=','>,
#  <Token id=65493 source='его'>,
#  <Token id=65494 source='надломила'>,
#  <Token id=65495 source='нечаянная'>,
#  <Token id=65496 source='смерть'>,
#  <Token id=65497 source='Олега'>,
#  <Token id=65498 source=','>,
#  <Token id=65499 source='а'>,
#  <Token id=65500 source='может'>,
#  <Token id=65501 source='—'>,
#  <Token id=65502 source='разлагающее'>,
#  <Token id=65503 source='влияние'>,
#  <Token id=65504 source='греческих'>,
#  <Token id=65505 source='попов'>,
#  <Token id=65506 source=','>,
#  <Token id=65507 source='которых'>,
#  <Token id=65508 source='привечала'>,
#  <Token id=65509 source='его'>,
#  <Token id=65510 source='бабка'>,
#  <Token id=65511 source='Ольга'>,
#  <Token id=65512 source='('>,
#  <Token id=65513 source='иногда'>,
#  <Token id=65514 source='говорят'>,
#  <Token id=65515 source=','>,
#  <Token id=65516 source='что'>,
#  <Token id=65517 source='он'>,
#  <Token id=65518 source='и'>,
#  <Token id=65519 source='сам'>,
#  <Token id=65520 source='был'>,
#  <Token id=65521 source='христианином'>,
#  <Token id=65522 source=')'>,
#  <Token id=65523 source='.'>,
#  <Token id=65524 source='Как'>,
#  <Token id=65525 source='бы'>,
#  <Token id=65526 source='то'>,
#  <Token id=65527 source='ни'>,
#  <Token id=65528 source='было'>,
#  <Token id=65529 source=','>,
#  <Token id=65530 source='вместо'>,
#  <Token id=65531 source='того'>,
#  <Token id=65532 source='чтобы'>,
#  <Token id=65533 source='сражаться'>,
#  <Token id=65534 source=','>,
#  <Token id=65535 source='Ярополк'>,
#  <Token id=65536 source='решил'>,
#  <Token id=65537 source='отсидеться'>,
#  <Token id=65538 source='за'>,
#  <Token id=65539 source='стенами'>,
#  <Token id=65540 source='Киева'>,
#  <Token id=65541 source='.'>,
#  <Token id=65542 source='Хуже'>,
#  <Token id=65543 source='всего'>,
#  <Token id=65544 source='то'>,
#  <Token id=65545 source=','>,
#  <Token id=65546 source='что'>,
#  <Token id=65547 source='он'>,
#  <Token id=65548 source='слишком'>,
#  <Token id=65549 source='доверял'>,
#  <Token id=65550 source='своему'>,
#  <Token id=65551 source='воеводе'>,
#  <Token id=65552 source=','>,
#  <Token id=65553 source='носившему'>,
#  <Token id=65554 source='говорящее'>,
#  <Token id=65555 source='имя'>,
#  <Token id=65556 source='Блуд'>,
#  <Token id=65557 source='.'>,
#  <Token id=65558 source='Этот'>,
#  <Token id=65559 source='Блуд'>,
#  <Token id=65560 source='вступил'>,
#  <Token id=65561 source='в'>,
#  <Token id=65562 source='переговоры'>,
#  <Token id=65563 source='с'>,
#  <Token id=65564 source='Владимиром'>,
#  <Token id=65565 source=','>,
#  <Token id=65566 source='советовал'>,
#  <Token id=65567 source='всякие'>,
#  <Token id=65568 source='глупости'>,
#  <Token id=65569 source='и'>,
#  <Token id=65570 source='в'>,
#  <Token id=65571 source='конце'>,
#  <Token id=65572 source='концов'>,
#  <Token id=65573 source='сдал'>,
#  <Token id=65574 source='своего'>,
#  <Token id=65575 source='князя'>,
#  <Token id=65576 source='с'>,
#  <Token id=65577 source='головой'>,
#  <Token id=65578 source='.'>,
#  <Token id=65579 source='Посоветовал'>,
#  <Token id=65580 source='пойти'>,
#  <Token id=65581 source='к'>,
#  <Token id=65582 source='Владимиру'>,
#  <Token id=65583 source='и'>,
#  <Token id=65584 source='сказать'>,
#  <Token id=65585 source=':'>,
#  <Token id=65586 source='«'>,
#  <Token id=65587 source='Что'>,
#  <Token id=65588 source='ты'>,
#  <Token id=65589 source='мне'>,
#  <Token id=65590 source='ни'>,
#  <Token id=65591 source='дашь'>,
#  <Token id=65592 source=','>,
#  <Token id=65593 source='то'>,
#  <Token id=65594 source='я'>,
#  <Token id=65595 source='и'>,
#  <Token id=65596 source='приму'>,
#  <Token id=65597 source='»'>,
#  <Token id=65598 source='.'>,
#  <Token id=65599 source='Ярополка'>,
#  <Token id=65600 source='отговаривали'>,
#  <Token id=65601 source=','>,
#  <Token id=65602 source='но'>,
#  <Token id=65603 source='он'>,
#  <Token id=65604 source='пошёл'>,
#  <Token id=65605 source='.'>,
#  <Token id=65606 source='«'>,
#  <Token id=65607 source='Когда'>,
#  <Token id=65608 source='же'>,
#  <Token id=65609 source='входил'>,
#  <Token id=65610 source='в'>,
#  <Token id=65611 source='двери'>,
#  <Token id=65612 source=','>,
#  <Token id=65613 source='два'>,
#  <Token id=65614 source='варяга'>,
#  <Token id=65615 source='подняли'>,
#  <Token id=65616 source='его'>,
#  <Token id=65617 source='мечами'>,
#  <Token id=65618 source='под'>,
#  <Token id=65619 source='пазуxи'>,
#  <Token id=65620 source='.'>,
#  <Token id=65621 source='Блуд'>,
#  <Token id=65622 source='же'>,
#  <Token id=65623 source='затворил'>,
#  <Token id=65624 source='двери'>,
#  <Token id=65625 source='и'>,
#  <Token id=65626 source='не'>,
#  <Token id=65627 source='дал'>,
#  <Token id=65628 source='войти'>,
#  <Token id=65629 source='за'>,
#  <Token id=65630 source='ним'>,
#  <Token id=65631 source='своим'>,
#  <Token id=65632 source='.'>,
#  <Token id=65633 source='И'>,
#  <Token id=65634 source='так'>,
#  <Token id=65635 source='убит'>,
#  <Token id=65636 source='был'>,
#  <Token id=65637 source='Ярополк'>,
#  <Token id=65638 source='»'>,
#  <Token id=65639 source='.'>,
#  <Token id=65640 source='После'>,
#  <Token id=65641 source='этого'>,
#  <Token id=65642 source='убийца'>,
#  <Token id=65643 source='овладел'>,
#  <Token id=65644 source='женой'>,
#  <Token id=65645 source='брата'>,
#  <Token id=65646 source=','>,
#  <Token id=65647 source='в'>,
#  <Token id=65648 source='прошлом'>,
#  <Token id=65649 source='—'>,
#  <Token id=65650 source='греческой'>,
#  <Token id=65651 source='монахиней'>,
#  <Token id=65652 source='.'>,
#  <Token id=65653 source='«'>,
#  <Token id=65654 source='Повесть'>,
#  <Token id=65655 source='временных'>,
#  <Token id=65656 source='лет'>,
#  <Token id=65657 source='»'>,
#  <Token id=65658 source='сообщает'>,
#  <Token id=65659 source=':'>,
#  <Token id=65660 source='«'>,
#  <Token id=65661 source='Была'>,
#  <Token id=65662 source='она'>,
#  <Token id=65663 source='беременна'>,
#  <Token id=65664 source=','>,
#  <Token id=65665 source='и'>,
#  <Token id=65666 source='родился'>,
#  <Token id=65667 source='от'>,
#  <Token id=65668 source='неё'>,
#  <Token id=65669 source='Святополк'>,
#  <Token id=65670 source='»'>,
#  <Token id=65671 source='.'>,
#  <Token id=65672 source='И'>,
#  <Token id=65673 source='далее'>,
#  <Token id=65674 source=':'>,
#  <Token id=65675 source='«'>,
#  <Token id=65676 source='Потому'>,
#  <Token id=65677 source='-'>,
#  <Token id=65678 source='то'>,
#  <Token id=65679 source='и'>,
#  <Token id=65680 source='не'>,
#  <Token id=65681 source='любил'>,
#  <Token id=65682 source='Святополка'>,
#  <Token id=65683 source='отец'>,
#  <Token id=65684 source='его'>,
#  <Token id=65685 source=','>,
#  <Token id=65686 source='что'>,
#  <Token id=65687 source='был'>,
#  <Token id=65688 source='он'>,
#  <Token id=65689 source='от'>,
#  <Token id=65690 source='двух'>,
#  <Token id=65691 source='отцов'>,
#  <Token id=65692 source=':'>,
#  <Token id=65693 source='от'>,
#  <Token id=65694 source='Ярополка'>,
#  <Token id=65695 source='и'>,
#  <Token id=65696 source='от'>,
#  <Token id=65697 source='Владимира'>,
#  <Token id=65698 source='»'>,
#  <Token id=65699 source='.'>,
#  <Token id=65700 source='Православные'>,
#  <Token id=65701 source='историки'>,
#  <Token id=65702 source='называют'>,
#  <Token id=65703 source='Святополка'>,
#  <Token id=65704 source='Окаянного'>,
#  <Token id=65705 source='пасынком'>,
#  <Token id=65706 source='Владимира'>,
#  <Token id=65707 source='.'>,
#  <Token id=65708 source='Но'>,
#  <Token id=65709 source='точно'>,
#  <Token id=65710 source='установить'>,
#  <Token id=65711 source=','>,
#  <Token id=65712 source='чьим'>,
#  <Token id=65713 source='он'>,
#  <Token id=65714 source='был'>,
#  <Token id=65715 source='сыном'>,
#  <Token id=65716 source=','>,
#  <Token id=65717 source='а'>,
#  <Token id=65718 source='чьим'>,
#  <Token id=65719 source='пасынком'>,
#  <Token id=65720 source=','>,
#  <Token id=65721 source='теперь'>,
#  <Token id=65722 source='уже'>,
#  <Token id=65723 source='невозможно'>,
#  <Token id=65724 source='.'>,
#  <Token id=65725 source='Да'>,
#  <Token id=65726 source='это'>,
#  <Token id=65727 source='и'>,
#  <Token id=65728 source='неважно'>,
#  <Token id=65729 source='.'>,
#  <Token id=65730 source='У'>,
#  <Token id=65731 source='Владимира'>,
#  <Token id=65732 source='было'>,
#  <Token id=65733 source='столько'>,
#  <Token id=65734 source='детей'>,
#  <Token id=65735 source=','>,
#  <Token id=65736 source='жён'>,
#  <Token id=65737 source='и'>,
#  <Token id=65738 source='наложниц'>,
#  <Token id=65739 source=','>,
#  <Token id=65740 source='что'>,
#  <Token id=65741 source='можно'>,
#  <Token id=65742 source='только'>,
#  <Token id=65743 source='позавидовать'>,
#  <Token id=65744 source='.'>,
#  <Token id=65745 source='Летописец'>,
#  <Token id=65746 source='даёт'>,
#  <Token id=65747 source='подробный'>,
#  <Token id=65748 source='каталог'>,
#  <Token id=65749 source='его'>,
#  <Token id=65750 source='гарема'>,
#  <Token id=65751 source='.'>,
#  <Token id=65752 source='Это'>,
#  <Token id=65753 source='стоит'>,
#  <Token id=65754 source='почитать'>,
#  <Token id=65755 source=':'>,
#  <Token id=65756 source='«'>,
#  <Token id=65757 source='И'>,
#  <Token id=65758 source='были'>,
#  <Token id=65759 source='у'>,
#  <Token id=65760 source='него'>,
#  <Token id=65761 source='жёны'>,
#  <Token id=65762 source=':'>,
#  <Token id=65763 source='Рогнеда'>,
#  <Token id=65764 source=','>,
#  <Token id=65765 source='которую'>,
#  <Token id=65766 source='поселил'>,
#  <Token id=65767 source='на'>,
#  <Token id=65768 source='Лыбеди'>,
#  <Token id=65769 source=','>,
#  <Token id=65770 source='где'>,
#  <Token id=65771 source='ныне'>,
#  <Token id=65772 source='находится'>,
#  <Token id=65773 source='сельцо'>,
#  <Token id=65774 source='Предславино'>,
#  <Token id=65775 source=','>,
#  <Token id=65776 source='от'>,
#  <Token id=65777 source='неё'>,
#  <Token id=65778 source='имел'>,
#  <Token id=65779 source='он'>,
#  <Token id=65780 source='четырёх'>,
#  <Token id=65781 source='сыновей'>,
#  <Token id=65782 source=':'>,
#  <Token id=65783 source='Изяслава'>,
#  <Token id=65784 source=','>,
#  <Token id=65785 source='Мстислава'>,
#  <Token id=65786 source=','>,
#  <Token id=65787 source='Ярослава'>,
#  <Token id=65788 source=','>,
#  <Token id=65789 source='Всеволода'>,
#  <Token id=65790 source='и'>,
#  <Token id=65791 source='двух'>,
#  <Token id=65792 source='дочерей'>,
#  <Token id=65793 source=';'>,
#  <Token id=65794 source='от'>,
#  <Token id=65795 source='гречанки'>,
#  <Token id=65796 source='имел'>,
#  <Token id=65797 source='он'>,
#  <Token id=65798 source='Святополка'>,
#  <Token id=65799 source=','>,
#  <Token id=65800 source='от'>,
#  <Token id=65801 source='чехини'>,
#  <Token id=65802 source='—'>,
#  <Token id=65803 source='Вышеслава'>,
#  <Token id=65804 source=','>,
#  <Token id=65805 source='а'>,
#  <Token id=65806 source='ещё'>,
#  <Token id=65807 source='от'>,
#  <Token id=65808 source='одной'>,
#  <Token id=65809 source='жены'>,
#  <Token id=65810 source='—'>,
#  <Token id=65811 source='Святослава'>,
#  <Token id=65812 source='и'>,
#  <Token id=65813 source='Мстислава'>,
#  <Token id=65814 source=','>,
#  <Token id=65815 source='а'>,
#  <Token id=65816 source='от'>,
#  <Token id=65817 source='болгарыни'>,
#  <Token id=65818 source='—'>,
#  <Token id=65819 source='Бориса'>,
#  <Token id=65820 source='и'>,
#  <Token id=65821 source='Глеба'>,
#  <Token id=65822 source=','>,
#  <Token id=65823 source='а'>,
#  <Token id=65824 source='наложниц'>,
#  <Token id=65825 source='было'>,
#  <Token id=65826 source='у'>,
#  <Token id=65827 source='него'>,
#  <Token id=65828 source='300'>,
#  <Token id=65829 source='в'>,
#  <Token id=65830 source='Вышгороде'>,
#  <Token id=65831 source=','>,
#  <Token id=65832 source='300'>,
#  <Token id=65833 source='в'>,
#  <Token id=65834 source='Белгороде'>,
#  <Token id=65835 source='и'>,
#  <Token id=65836 source='200'>,
#  <Token id=65837 source='на'>,
#  ...]

# %%
sent = doc.sentences[6]
sent
# Out:
# <Sentence id=3439 source='У князя Святослава Игоревича было три сына: Ярополк, Олег и Владимир.'>

# %%
sent.tokens
# Out:
# [<Token id=64912 source='У'>,
#  <Token id=64913 source='князя'>,
#  <Token id=64914 source='Святослава'>,
#  <Token id=64915 source='Игоревича'>,
#  <Token id=64916 source='было'>,
#  <Token id=64917 source='три'>,
#  <Token id=64918 source='сына'>,
#  <Token id=64919 source=':'>,
#  <Token id=64920 source='Ярополк'>,
#  <Token id=64921 source=','>,
#  <Token id=64922 source='Олег'>,
#  <Token id=64923 source='и'>,
#  <Token id=64924 source='Владимир'>,
#  <Token id=64925 source='.'>]

# %%
token = sent[1]
token.source
# Out:
# 'князя'

# %%
token.grammemes[0]
# Out:
# 'NOUN'

# %% [markdown]
# Для дальнейшей работы я беру **10 000 предложений** из своего корпуса.

# %%
document = corpus.sentences[0:10000]
document[0]
# Out:
# <Sentence id=1 source='«Школа злословия» учит прикусить язык'>

# %% [markdown]
# Привожу данные к формату, который нужно подать в языковые модели.
# Предложения разбиваются на токены, и каждому токену в соответствие ставится POS-тег.

# %%
data = list()

for sent in document:
    sentence = list()
    for token in sent.tokens:
        t = (token.source, token.grammemes[0])
        sentence.append(t)
    data.append(sentence)

# %%
len(data)
# Out:
# 10000

# %% [markdown]
# Пример данных.

# %%
data[0:3]
# Out:
# [[('«', 'PNCT'),
#   ('Школа', 'NOUN'),
#   ('злословия', 'NOUN'),
#   ('»', 'PNCT'),
#   ('учит', 'VERB'),
#   ('прикусить', 'INFN'),
#   ('язык', 'NOUN')],
#  [('Сохранится', 'VERB'),
#   ('ли', 'PRCL'),
#   ('градус', 'NOUN'),
#   ('дискуссии', 'NOUN'),
#   ('в', 'PREP'),
#   ('новом', 'ADJF'),
#   ('сезоне', 'NOUN'),
#   ('?', 'PNCT')],
#  [('Великолепная', 'ADJF'),
#   ('«', 'PNCT'),
#   ('Школа', 'NOUN'),
#   ('злословия', 'NOUN'),
#   ('»', 'PNCT'),
#   ('вернулась', 'VERB'),
#   ('в', 'PREP'),
#   ('эфир', 'NOUN'),
#   ('после', 'PREP'),
#   ('летних', 'ADJF'),
#   ('каникул', 'NOUN'),
#   ('в', 'PREP'),
#   ('новом', 'ADJF'),
#   ('формате', 'NOUN'),
#   ('.', 'PNCT')]]

# %% [markdown]
# Делю данные на train, test. 80% данных - обучающая выборка, 20% - тестовая.

# %%
train_data = data[:8000]
test_data = data[8000:]

len(train_data), len(test_data)
# Out:
# (8000, 2000)

# %% [markdown]
# ## Обучение языковой модели

# %% [markdown]
# Сделаю комбинацию из нескольких анализаторов. В начале использую анализатор по умолчанию, он автоматически ставит 1 тег каждому слову. В качестве тега я взяла NOUN, т.к. имя существительное - это самая часто встречаемая часть речи в предложениях. Далее, последовательно применяю Unigram, Bigram и Trigram теггеры.

# %%
default_tagger = nltk.DefaultTagger('NOUN')
unigram_tagger = nltk.UnigramTagger(train_data, backoff=default_tagger)
bigram_tagger = nltk.BigramTagger(train_data, backoff=unigram_tagger)
trigram_tagger = nltk.TrigramTagger(train_data, backoff=bigram_tagger)

# %% [markdown]
# ## Оценка точности

# %% [markdown]
# Оценю 2 модели.

# %%
bigram_tagger.evaluate(test_data)
# Out:
# 0.8705773066309663

# %%
trigram_tagger.evaluate(test_data)
# Out:
# 0.8698942651840114

# %% [markdown]
# Точность у Bigram model оказалась выше, чем у Trigram model.

# %% [markdown]
# Пробую предсказать теги для неразмеченных предложений, не участвовавших в обучении и оценке.

# %%
doc_ = corpus.sentences[10100:10200]

test_notags, test_tags = list(), list()
for s in doc_:
    sent, tags = list(), list()
    for token in s.tokens:
        sent.append(token.source)
        tags.append(token.grammemes[0])
    test_notags.append(sent)
    test_tags.append(tags)

len(test_notags), len(test_tags)
# Out:
# (100, 100)

# %% [markdown]
# Проверю 2 модели на 2 предложениях.

# %% [markdown]
# * **1-ое предложение**

# %%
print(bigram_tagger.tag(test_notags[99]))
# Out:
# [('Что', 'CONJ'), ('случилось', 'VERB'), ('с', 'PREP'), ('поездом', 'NOUN'), ('?', 'PNCT')]

# %%
print(trigram_tagger.tag(test_notags[99]))
# Out:
# [('Что', 'CONJ'), ('случилось', 'VERB'), ('с', 'PREP'), ('поездом', 'NOUN'), ('?', 'PNCT')]

# %% [markdown]
# Сверю с настоящей разметкой.

# %%
test_tags[99]
# Out:
# ['CONJ', 'VERB', 'PREP', 'NOUN', 'PNCT']

# %% [markdown]
# Всё совпало.

# %% [markdown]
# * **2-ое предложение**

# %%
print(bigram_tagger.tag(test_notags[4]))
print(trigram_tagger.tag(test_notags[4]))
print(test_tags[4])
# Out:
# [('25', 'NUMB'), ('марта', 'NOUN'), ('2010', 'NUMB'), ('года', 'NOUN'), ('Рустам', 'NOUN'), ('Нургалиевич', 'NOUN'), ('Минниханов', 'NOUN'), ('принес', 'VERB'), ('присягу', 'NOUN'), ('и', 'CONJ'), ('вступил', 'VERB'), ('в', 'PREP'), ('должность', 'NOUN'), ('президента', 'NOUN'), ('Руспублики', 'NOUN'), ('Татарстан', 'NOUN'), ('.', 'PNCT')]
# [('25', 'NUMB'), ('марта', 'NOUN'), ('2010', 'NUMB'), ('года', 'NOUN'), ('Рустам', 'NOUN'), ('Нургалиевич', 'NOUN'), ('Минниханов', 'NOUN'), ('принес', 'VERB'), ('присягу', 'NOUN'), ('и', 'CONJ'), ('вступил', 'VERB'), ('в', 'PREP'), ('должность', 'NOUN'), ('президента', 'NOUN'), ('Руспублики', 'NOUN'), ('Татарстан', 'NOUN'), ('.', 'PNCT')]
# ['NUMB', 'NOUN', 'NUMB', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'CONJ', 'VERB', 'PREP', 'NOUN', 'NOUN', 'UNKN', 'NOUN', 'PNCT']

# %% [markdown]
# Теги определены правильно в каждом случае.

# %% [markdown]
# Сохраню лучшую модель.

# %%
from pickle import dump
output = open('bigram.pkl', 'wb')
dump(bigram_tagger, output, -1)
output.close()

# %% [markdown]
# # Часть 2
# **Для нескольких текстов из собранного новостного датасета выполнить разметку частей речи и
# именованных сущностей, проанализировать ошибки алгоритма.**

# %% [markdown]
# ## Чтение и предобработка данных

# %%
xmlstr = codecs.open('dataPatina.xml', encoding='utf-8', mode='r').read()
root = etree.fromstring(xmlstr)

catalog = list()
for element_lvl1 in root:
    article = {}
    for element_lvl2 in element_lvl1:
        txt = element_lvl2.text
        article[element_lvl2.tag] = '' if txt is None else txt
    catalog.append(article)

# %%
def preprocessing(text):
    return re.sub( '\s+', ' ', text).strip()

data = list()
for i in range(len(catalog)):
    data.append(preprocessing(catalog[i]['text']))

# %%
len(data)
# Out:
# 200

# %% [markdown]
# Я хочу найти короткие тексты, чтобы было удобнее анализировать разметку.

# %%
ind = list()
for i in range(len(data)):
    if len(data[i])<900 and len(data[i])>100:
        ind.append(i)

len(ind)
# Out:
# 71

# %% [markdown]
# Из 71 текста выберу 2 для анализа.

# %%
data[ind[6]]
# Out:
# "Video The nominations for this year's Academy Awards have been announced, Joker leading the pack with 11 nods. The comic book villain origin story is up for best picture, best director and best actor for Joaquin Phoenix, plus eight other awards. The Irishman, 1917 and Once Upon a Time in Hollywood follow with 10 nominations each. But who else has been nominated?"

# %%
print(data[1]) # the same - data[ind[0]]
# Out:
# This story is nominated for a Webby Award for Best Film & Video. Vote here. BBC Earth is also nominated for a Webby, for Best Science Website. Vote here. In theory this is not the only Universe that might exist, and in many others, identical copies of us can be found. The question is, how do we get there? BBC Earth's Melissa Hogenboom goes on the hunt for her cosmic twin. Melissa Hogenboom is BBC Earth's feature writer. She is @melissasuzanneh on Twitter. Video produced by Pierangelo Pirak; he is @ppirak on twitter. Join over five million BBC Earth fans by liking us on Facebook, or follow us on Twitter and Instagram. If you liked this story, sign up for the weekly bbc.com features newsletter called "If You Only Read 6 Things This Week". A handpicked selection of stories from BBC Future, Earth, Culture, Capital, Travel and Autos, delivered to your inbox every Friday.

# %% [markdown]
# ## Разметка

# %% [markdown]
# Для каждого текста
# * построю таблицу, в которой для каждого токена текста показывается его лемма, pos-tag, детализированный pos-tag, синтаксическая зависимость, форма слова и принадлежность токена к набору стоп-слов;
# * сделаю dependency parsing;
# * named entity recognition.

# %%
nlp = spacy.load('en_core_web_sm')
PIPELINE = ['tagger', 'parser', 'ner']
names_col = ['TEXT', 'LEMMA', 'POS', 'TAG', 'DEP', 'SHAPE', 'STOP']

# %% [markdown]
# * **ТЕКСТ 1**

# %%
doc1 = nlp(data[1])

# %%
doc1
# Out:
# This story is nominated for a Webby Award for Best Film & Video. Vote here. BBC Earth is also nominated for a Webby, for Best Science Website. Vote here. In theory this is not the only Universe that might exist, and in many others, identical copies of us can be found. The question is, how do we get there? BBC Earth's Melissa Hogenboom goes on the hunt for her cosmic twin. Melissa Hogenboom is BBC Earth's feature writer. She is @melissasuzanneh on Twitter. Video produced by Pierangelo Pirak; he is @ppirak on twitter. Join over five million BBC Earth fans by liking us on Facebook, or follow us on Twitter and Instagram. If you liked this story, sign up for the weekly bbc.com features newsletter called "If You Only Read 6 Things This Week". A handpicked selection of stories from BBC Future, Earth, Culture, Capital, Travel and Autos, delivered to your inbox every Friday.

# %%
df1 = pd.DataFrame(columns=names_col)
for token in doc1:
    df1 = df1.append({'TEXT': token.text, 'LEMMA': token.lemma_, 'POS': token.pos_, 'TAG': token.tag_, 
                            'DEP': token.dep_, 'SHAPE': token.shape_, 'STOP': token.is_stop}, ignore_index=True)

# %%
df1.head(100)
# Out:
#                 TEXT             LEMMA    POS   TAG        DEP  SHAPE   STOP
# 0               This              this    DET    DT        det   Xxxx   True
# 1              story             story   NOUN    NN  nsubjpass   xxxx  False
# 2                 is                be    AUX   VBZ    auxpass     xx   True
# 3          nominated          nominate   VERB   VBN       ROOT   xxxx  False
# 4                for               for    ADP    IN       prep    xxx   True
# 5                  a                 a    DET    DT        det      x   True
# 6              Webby             Webby  PROPN   NNP   compound  Xxxxx  False
# 7              Award             Award  PROPN   NNP       pobj  Xxxxx  False
# 8                for               for    ADP    IN       prep    xxx   True
# 9               Best              Best  PROPN   NNP   compound   Xxxx  False
# 10              Film              Film  PROPN   NNP       pobj   Xxxx  False
# 11                 &                 &  CCONJ    CC         cc      &  False
# 12             Video             Video  PROPN   NNP       conj  Xxxxx  False
# 13                 .                 .  PUNCT     .      punct      .  False
# 14              Vote              vote   NOUN    NN       ROOT   Xxxx  False
# 15              here              here    ADV    RB     advmod   xxxx   True
# 16                 .                 .  PUNCT     .      punct      .  False
# 17               BBC               BBC  PROPN   NNP   compound    XXX  False
# 18             Earth             Earth  PROPN   NNP  nsubjpass  Xxxxx  False
# 19                is                be    AUX   VBZ    auxpass     xx   True
# 20              also              also    ADV    RB     advmod   xxxx   True
# 21         nominated          nominate   VERB   VBN       ROOT   xxxx  False
# 22               for               for    ADP    IN       prep    xxx   True
# 23                 a                 a    DET    DT        det      x   True
# 24             Webby             Webby  PROPN   NNP       pobj  Xxxxx  False
# 25                 ,                 ,  PUNCT     ,      punct      ,  False
# 26               for               for    ADP    IN       prep    xxx   True
# 27              Best              good    ADJ   JJS       amod   Xxxx  False
# 28           Science           Science  PROPN   NNP   compound  Xxxxx  False
# 29           Website           Website  PROPN   NNP       pobj  Xxxxx  False
# ..               ...               ...    ...   ...        ...    ...    ...
# 70             Earth             Earth  PROPN   NNP       poss  Xxxxx  False
# 71                's                's   PART   POS       case     'x   True
# 72           Melissa           Melissa  PROPN   NNP   compound  Xxxxx  False
# 73         Hogenboom         Hogenboom  PROPN   NNP      nsubj  Xxxxx  False
# 74              goes                go   VERB   VBZ       ROOT   xxxx  False
# 75                on                on    ADP    IN       prep     xx   True
# 76               the               the    DET    DT        det    xxx   True
# 77              hunt              hunt   NOUN    NN       pobj   xxxx  False
# 78               for               for    ADP    IN       prep    xxx   True
# 79               her            -PRON-    DET  PRP$       poss    xxx   True
# 80            cosmic            cosmic    ADJ    JJ       amod   xxxx  False
# 81              twin              twin   NOUN    NN       pobj   xxxx  False
# 82                 .                 .  PUNCT     .      punct      .  False
# 83           Melissa           Melissa  PROPN   NNP   compound  Xxxxx  False
# 84         Hogenboom         Hogenboom  PROPN   NNP      nsubj  Xxxxx  False
# 85                is                be    AUX   VBZ       ROOT     xx   True
# 86               BBC               BBC  PROPN   NNP   compound    XXX  False
# 87             Earth             Earth  PROPN   NNP       poss  Xxxxx  False
# 88                's                's   PART   POS       case     'x   True
# 89           feature           feature   NOUN    NN   compound   xxxx  False
# 90            writer            writer   NOUN    NN       attr   xxxx  False
# 91                 .                 .  PUNCT     .      punct      .  False
# 92               She            -PRON-   PRON   PRP      nsubj    Xxx   True
# 93                is                be    AUX   VBZ       ROOT     xx   True
# 94  @melissasuzanneh  @melissasuzanneh    ADJ    JJ       attr  @xxxx  False
# 95                on                on    ADP    IN       prep     xx   True
# 96           Twitter           Twitter  PROPN   NNP       pobj  Xxxxx  False
# 97                 .                 .  PUNCT     .      punct      .  False
# 98             Video             video   NOUN    NN        dep  Xxxxx  False
# 99          produced           produce   VERB   VBN        acl   xxxx  False
#
# [100 rows x 7 columns]

# %% [markdown]
# В основном POS-теги расставлены правильно. Однако, ник акаунта в твиттере @melissasuzanneh, я бы определила к NOUN или X(other), а не к adjective. Также, если Science Website отнесены к имени собственному, то и Best тоже должно быть именем собственным.

# %%
for sent in doc1.sents:
    print(sent)
    displacy.render(sent, style='dep', jupyter=True, options={'compact': True, "bg": "ivory"})
# Out:
# This story is nominated for a Webby Award for Best Film & Video.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d5ca12091f2f467998eb22028460b526-0" class="displacy" width="1850" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">story</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">nominated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Webby</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Award</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Film &amp;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Video.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-1" stroke-width="2px" d="M212,227.0 212,177.0 497.0,177.0 497.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-2" stroke-width="2px" d="M362,227.0 362,202.0 494.0,202.0 494.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,229.0 L358,221.0 366,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-3" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M644.0,229.0 L648.0,221.0 640.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-4" stroke-width="2px" d="M812,227.0 812,177.0 1097.0,177.0 1097.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,229.0 L808,221.0 816,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-5" stroke-width="2px" d="M962,227.0 962,202.0 1094.0,202.0 1094.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M962,229.0 L958,221.0 966,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-6" stroke-width="2px" d="M662,227.0 662,152.0 1100.0,152.0 1100.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,229.0 L1104.0,221.0 1096.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d5ca12091f2f467998eb22028460b526-0-7" stroke-width="2px" d="M1112,227.0 1112,202.0 1244.0,202.0 1244.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d5ca12091f2f467998eb22028460b526-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1244.0,229.0 L1248.0,221.0 1240.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arr
# Vote here.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b2be20a891114e168708fe0b1830f4ce-0" class="displacy" width="350" height="212.0" direction="ltr" style="max-width: none; height: 212.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Vote</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">here.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2be20a891114e168708fe0b1830f4ce-0-0" stroke-width="2px" d="M62,77.0 62,52.0 200.0,52.0 200.0,77.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2be20a891114e168708fe0b1830f4ce-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M200.0,79.0 L204.0,71.0 196.0,71.0" fill="currentColor"/>
# </g>
# </svg>
# BBC Earth is also nominated for a Webby, for Best Science Website.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="042a4cef062949e59a2b69f7588ae442-0" class="displacy" width="1850" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">BBC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Earth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">nominated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Webby,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Website.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-1" stroke-width="2px" d="M212,227.0 212,152.0 650.0,152.0 650.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-2" stroke-width="2px" d="M362,227.0 362,177.0 647.0,177.0 647.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,229.0 L358,221.0 366,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-3" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,229.0 L508,221.0 516,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-4" stroke-width="2px" d="M662,227.0 662,202.0 794.0,202.0 794.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794.0,229.0 L798.0,221.0 790.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-5" stroke-width="2px" d="M962,227.0 962,202.0 1094.0,202.0 1094.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M962,229.0 L958,221.0 966,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-6" stroke-width="2px" d="M812,227.0 812,177.0 1097.0,177.0 1097.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1097.0,229.0 L1101.0,221.0 1093.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-042a4cef062949e59a2b69f7588ae442-0-7" stroke-width="2px" d="M1112,227.0 1112,202.0 1244.0,202.0 1244.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-042a4cef062949e59a2b69f7588ae442-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1244.0,229.0 L1248.0,221.0 1240.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow
# Vote here.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e17b78c1e452496f848e9329c739355a-0" class="displacy" width="350" height="212.0" direction="ltr" style="max-width: none; height: 212.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Vote</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">here.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e17b78c1e452496f848e9329c739355a-0-0" stroke-width="2px" d="M62,77.0 62,52.0 200.0,52.0 200.0,77.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e17b78c1e452496f848e9329c739355a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M200.0,79.0 L204.0,71.0 196.0,71.0" fill="currentColor"/>
# </g>
# </svg>
# In theory this is not the only Universe that might exist, and in many others, identical copies of us can be found.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cc267c8c692f450d90e52d399a28ba37-0" class="displacy" width="3350" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">theory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Universe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">might</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">exist,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">others,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">identical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">copies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">us</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">found.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc267c8c692f450d90e52d399a28ba37-0-0" stroke-width="2px" d="M62,602.0 62,527.0 485.0,527.0 485.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc267c8c692f450d90e52d399a28ba37-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,604.0 L58,596.0 66,596.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc267c8c692f450d90e52d399a28ba37-0-1" stroke-width="2px" d="M62,602.0 62,577.0 179.0,577.0 179.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc267c8c692f450d90e52d399a28ba37-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M179.0,604.0 L183.0,596.0 175.0,596.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc267c8c692f450d90e52d399a28ba37-0-2" stroke-width="2px" d="M362,602.0 362,577.0 479.0,577.0 479.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc267c8c692f450d90e52d399a28ba37-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,604.0 L358,596.0 366,596.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc267c8c692f450d90e52d399a28ba37-0-3" stroke-width="2px" d="M512,602.0 512,577.0 629.0,577.0 629.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc267c8c692f450d90e52d399a28ba37-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">neg</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M629.0,
# The question is, how do we get there?
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4b30e50e0bb14ce3918ae3fac6ee2787-0" class="displacy" width="1250" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">question</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">is,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">get</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">there?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-0" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-1" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-2" stroke-width="2px" d="M512,302.0 512,227.0 947.0,227.0 947.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,304.0 L508,296.0 516,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-3" stroke-width="2px" d="M662,302.0 662,252.0 944.0,252.0 944.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-4" stroke-width="2px" d="M812,302.0 812,277.0 941.0,277.0 941.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,304.0 L808,296.0 816,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-5" stroke-width="2px" d="M362,302.0 362,202.0 950.0,202.0 950.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950.0,304.0 L954.0,296.0 946.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-6" stroke-width="2px" d="M962,302.0 962,277.0 1091.0,277.0 1091.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b30e50e0bb14ce3918ae3fac6ee2787-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1091.0,304.0 L1095.0,296.0 1087.0,296.0" fill="currentColor"/>
# </g>
# </svg>
# BBC Earth's Melissa Hogenboom goes on the hunt for her cosmic twin.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b7e6e899c5b74a3493ae03c947551b84-0" class="displacy" width="2000" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">BBC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Earth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Melissa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Hogenboom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">goes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">hunt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">cosmic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">twin.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-0" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-1" stroke-width="2px" d="M212,302.0 212,227.0 647.0,227.0 647.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-2" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M341.0,304.0 L345.0,296.0 337.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-3" stroke-width="2px" d="M512,302.0 512,277.0 641.0,277.0 641.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,304.0 L508,296.0 516,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-4" stroke-width="2px" d="M662,302.0 662,277.0 791.0,277.0 791.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-5" stroke-width="2px" d="M812,302.0 812,277.0 941.0,277.0 941.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M941.0,304.0 L945.0,296.0 937.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-6" stroke-width="2px" d="M1112,302.0 1112,277.0 1241.0,277.0 1241.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1112,304.0 L1108,296.0 1116,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7e6e899c5b74a3493ae03c947551b84-0-7" stroke-width="2px" d="M962,302.0 962,252.0 1244.0,252.0 1244.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7e6e899c5b74a3493ae03c947551b84-0-7" class="displacy-label" startOffset="50%" side="left" fill="cu
# Melissa Hogenboom is BBC Earth's feature writer.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0e24a0a2be334f23bed2414845304c14-0" class="displacy" width="1250" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Melissa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Hogenboom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">BBC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Earth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">feature</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">writer.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0e24a0a2be334f23bed2414845304c14-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0e24a0a2be334f23bed2414845304c14-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0e24a0a2be334f23bed2414845304c14-0-1" stroke-width="2px" d="M212,227.0 212,202.0 344.0,202.0 344.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0e24a0a2be334f23bed2414845304c14-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0e24a0a2be334f23bed2414845304c14-0-2" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0e24a0a2be334f23bed2414845304c14-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,229.0 L508,221.0 516,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0e24a0a2be334f23bed2414845304c14-0-3" stroke-width="2px" d="M662,227.0 662,177.0 1097.0,177.0 1097.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0e24a0a2be334f23bed2414845304c14-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,229.0 L658,221.0 666,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0e24a0a2be334f23bed2414845304c14-0-4" stroke-width="2px" d="M662,227.0 662,202.0 794.0,202.0 794.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0e24a0a2be334f23bed2414845304c14-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794.0,229.0 L798.0,221.0 790.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0e24a0a2be334f23bed2414845304c14-0-5" stroke-width="2px" d="M962,227.0 962,202.0 1094.0,202.0 1094.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0e24a0a2be334f23bed2414845304c14-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M962,229.0 L958,221.0 966,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0e24a0a2be334f23bed2414845304c14-0-6" stroke-width="2px" d="M362,227.0 362,152.0 1100.0,152.0 1100.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0e24a0a2be334f23bed2414845304c14-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,229.0 L1104.0,221.0 1096.0,221.0" fill="currentColor"/>
# </g>
# </svg>
# She is @melissasuzanneh on Twitter.
# ...
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">called &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1b6c30405ba49c78e152b8744e9c03d-0-0" stroke-width="2px" d="M62,77.0 62,52.0 200.0,52.0 200.0,77.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1b6c30405ba49c78e152b8744e9c03d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M200.0,79.0 L204.0,71.0 196.0,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1b6c30405ba49c78e152b8744e9c03d-0-1" stroke-width="2px" d="M212,77.0 212,52.0 350.0,52.0 350.0,77.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1b6c30405ba49c78e152b8744e9c03d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350.0,79.0 L354.0,71.0 346.0,71.0" fill="currentColor"/>
# </g>
# </svg>
# If You Only Read 6 Things This Week".
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="83fa3050375544f59aa8075d630d1c9b-0" class="displacy" width="1250" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">If</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">You</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Read</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Things</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Week&quot;.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-83fa3050375544f59aa8075d630d1c9b-0-0" stroke-width="2px" d="M62,302.0 62,227.0 497.0,227.0 497.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-83fa3050375544f59aa8075d630d1c9b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-83fa3050375544f59aa8075d630d1c9b-0-1" stroke-width="2px" d="M212,302.0 212,252.0 494.0,252.0 494.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-83fa3050375544f59aa8075d630d1c9b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-83fa3050375544f59aa8075d630d1c9b-0-2" stroke-width="2px" d="M362,302.0 362,277.0 491.0,277.0 491.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-83fa3050375544f59aa8075d630d1c9b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,304.0 L358,296.0 366,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-83fa3050375544f59aa8075d630d1c9b-0-3" stroke-width="2px" d="M662,302.0 662,277.0 791.0,277.0 791.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-83fa3050375544f59aa8075d630d1c9b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-83fa3050375544f59aa8075d630d1c9b-0-4" stroke-width="2px" d="M512,302.0 512,252.0 794.0,252.0 794.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-83fa3050375544f59aa8075d630d1c9b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794.0,304.0 L798.0,296.0 790.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-83fa3050375544f59aa8075d630d1c9b-0-5" stroke-width="2px" d="M962,302.0 962,277.0 1091.0,277.0 1091.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-83fa3050375544f59aa8075d630d1c9b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M962,304.0 L958,296.0 966,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-83fa3050375544f59aa8075d630d1c9b-0-6" stroke-width="2px" d="M512,302.0 512,202.0 1100.0,202.0 1100.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-83fa3050375544f59aa8075d630d1c9b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,304.0 L1104.0,296.0 1096.0,296.0" fill="currentColor"/>
# </g>
# </svg>
# A handpicked selection of stories from BBC Future, Earth, Culture, Capital, Travel and Autos, delivered to your inbox every Friday.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="884deadcbb364bc18dfad6d251a9ce78-0" class="displacy" width="3050" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">handpicked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">selection</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">stories</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">BBC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Future,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Earth,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Culture,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Capital,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Travel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Autos,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">delivered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">inbox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">every</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">Friday.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-884deadcbb364bc18dfad6d251a9ce78-0-0" stroke-width="2px" d="M62,302.0 62,252.0 344.0,252.0 344.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-884deadcbb364bc18dfad6d251a9ce78-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-884deadcbb364bc18dfad6d251a9ce78-0-1" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-884deadcbb364bc18dfad6d251a9ce78-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-884deadcbb364bc18dfad6d251a9ce78-0-2" stroke-width="2px" d="M362,302.0 362,277.0 491.0,277.0 491.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-884deadcbb364bc18dfad6d251a9ce78-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M491.0,304.0 L495.0,296.0 487.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-884deadcbb364bc18dfad6d251a9ce78-0-3" stroke-width="2px" d="M512,302.0 512,277.0 641.0,277.0 641.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-884deadcbb364bc18dfad6d251a9ce78-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M641.0,304.0 L645.0,296.0 637.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-884deadcbb364bc18dfad6d251a9ce78-0-4" stroke-width="2px" d="M662,302.0 662,277.0 791.0,277.0 791.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-884deadcbb364bc18dfad6d251a9ce78-0-4" class="displacy-label" startOffset="50%" si

# %% [markdown]
# На мой взгляд зависимости определяются правильно.

# %%
displacy.render(doc1, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">This story is nominated for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a Webby Award for
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Best Film &amp; Video
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Vote here.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is also nominated for a
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Webby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Best Science Website
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Vote here. In theory this is not the only Universe that might exist, and in many others, identical copies of us can be found. The question is, how do we get there?
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC Earth's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Hogenboom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  goes on the hunt for her cosmic twin.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Hogenboom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC Earth's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  feature writer. She is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     @melissasuzanneh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# . Video produced by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pierangelo Pirak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ; he is @ppirak on twitter. Join over five million
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fans by liking us on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , or follow us on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Instagram. If you liked this story, sign up for the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  bbc.com features newsletter called &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     If You Only Read 6 Things This Week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot;. A handpicked selection of stories from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC Future
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , Culture, Capital,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and Autos, delivered to your inbox every Friday.</div>

# %% [markdown]
# С поиском именованных сущностей дела обстоят хуже, довольно много ошибок. Webby Award должно быть - EVENT или WORK_OF_ART, причём a,for не должны быть выделены, а Twitter, Facebook должны определяться как тег - ORG. Best Film & Video, BBC Earth, Best Science Website, BBC Future, @melissasuzanneh я также отнесла бы к другим категориям. Не выделены такие сущности как: Instagram, @ppirak, five million, Universe. Travel не верно определилось, я бы вообще не отнесла это слово даже к сущности.  Если не учитывать контекст, то Webby можно принять за имя, иначе это должно относиться к другой категории.

# %% [markdown]
# * **ТЕКСТ 2**

# %%
doc2 = nlp(data[ind[6]])

# %%
doc2
# Out:
# Video The nominations for this year's Academy Awards have been announced, Joker leading the pack with 11 nods. The comic book villain origin story is up for best picture, best director and best actor for Joaquin Phoenix, plus eight other awards. The Irishman, 1917 and Once Upon a Time in Hollywood follow with 10 nominations each. But who else has been nominated?

# %%
df2 = pd.DataFrame(columns=names_col)
for token in doc2:
    df2 = df2.append({'TEXT': token.text, 'LEMMA': token.lemma_, 'POS': token.pos_, 'TAG': token.tag_, 
                            'DEP': token.dep_, 'SHAPE': token.shape_, 'STOP': token.is_stop}, ignore_index=True)

# %%
df2
# Out:
#            TEXT       LEMMA    POS   TAG        DEP  SHAPE   STOP
# 0         Video       Video  PROPN   NNP       ROOT  Xxxxx  False
# 1           The         the    DET    DT        det    Xxx   True
# 2   nominations  nomination   NOUN   NNS  nsubjpass   xxxx  False
# 3           for         for    ADP    IN       prep    xxx   True
# 4          this        this    DET    DT        det   xxxx   True
# 5          year        year   NOUN    NN       poss   xxxx  False
# 6            's          's   PART   POS       case     'x   True
# 7       Academy     Academy  PROPN   NNP   compound  Xxxxx  False
# 8        Awards      Awards  PROPN  NNPS       pobj  Xxxxx  False
# 9          have        have    AUX   VBP        aux   xxxx   True
# 10         been          be    AUX   VBN    auxpass   xxxx   True
# 11    announced    announce   VERB   VBN       ROOT   xxxx  False
# 12            ,           ,  PUNCT     ,      punct      ,  False
# 13        Joker       Joker  PROPN   NNP      nsubj  Xxxxx  False
# 14      leading        lead   VERB   VBG      advcl   xxxx  False
# 15          the         the    DET    DT        det    xxx   True
# 16         pack        pack   NOUN    NN       dobj   xxxx  False
# 17         with        with    ADP    IN       prep   xxxx   True
# 18           11          11    NUM    CD     nummod     dd  False
# 19         nods         nod   NOUN   NNS       pobj   xxxx  False
# 20            .           .  PUNCT     .      punct      .  False
# 21          The         the    DET    DT        det    Xxx   True
# 22        comic       comic    ADJ    JJ       amod   xxxx  False
# 23         book        book   NOUN    NN      nsubj   xxxx  False
# 24      villain     villain  PROPN   NNP   compound   xxxx  False
# 25       origin      origin   NOUN    NN   compound   xxxx  False
# 26        story       story   NOUN    NN      appos   xxxx  False
# 27           is          be    AUX   VBZ       ROOT     xx   True
# 28           up          up    ADV    RB     advmod     xx   True
# 29          for         for    ADP    IN       prep    xxx   True
# ..          ...         ...    ...   ...        ...    ...    ...
# 41            ,           ,  PUNCT     ,      punct      ,  False
# 42         plus        plus  CCONJ    CC         cc   xxxx  False
# 43        eight       eight    NUM    CD     nummod   xxxx   True
# 44        other       other    ADJ    JJ       amod   xxxx   True
# 45       awards       award   NOUN   NNS       conj   xxxx  False
# 46            .           .  PUNCT     .      punct      .  False
# 47          The         the    DET    DT        det    Xxx   True
# 48     Irishman    Irishman  PROPN   NNP      nsubj  Xxxxx  False
# 49            ,           ,  PUNCT     ,      punct      ,  False
# 50         1917        1917    NUM    CD      appos   dddd  False
# 51          and         and  CCONJ    CC         cc    xxx   True
# 52         Once        once    ADV    RB     advmod   Xxxx   True
# 53         Upon        upon  SCONJ    IN       prep   Xxxx   True
# 54            a           a    DET    DT        det      x   True
# 55         Time        time   NOUN    NN       pobj   Xxxx  False
# 56           in          in    ADP    IN       prep     xx   True
# 57    Hollywood   Hollywood  PROPN   NNP       pobj  Xxxxx  False
# 58       follow      follow   VERB    VB       ROOT   xxxx  False
# 59         with        with    ADP    IN       prep   xxxx   True
# 60           10          10    NUM    CD     nummod     dd  False
# 61  nominations  nomination   NOUN   NNS       pobj   xxxx  False
# 62         each        each    DET    DT      appos   xxxx   True
# 63            .           .  PUNCT     .      punct      .  False
# 64          But         but  CCONJ    CC         cc    Xxx   True
# 65          who         who   PRON    WP  nsubjpass    xxx   True
# 66         else        else    ADV    RB     advmod   xxxx   True
# 67          has        have    AUX   VBZ        aux    xxx   True
# 68         been          be    AUX   VBN    auxpass   xxxx   True
# 69    nominated    nominate   VERB   VBN       ROOT   xxxx  False
# 70            ?           ?  PUNCT     .      punct      ?  False
#
# [71 rows x 7 columns]

# %% [markdown]
# Я думаю, что слово villain не относится к proper noun, а относится просто к noun.

# %%
for sent in doc2.sents:
    print(sent)
    displacy.render(sent, style='dep', jupyter=True, options={'compact': True, "bg": "ivory"})
# Out:
# Video
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6c09ae5d6e72471aaaef2e8464c1835b-0" class="displacy" width="200" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Video</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# The nominations for this year's Academy Awards have been announced, Joker leading the pack with 11 nods.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b9431fa03d1949eb8ed74ace92a9bf59-0" class="displacy" width="2750" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">nominations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">year</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Academy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Awards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">announced,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Joker</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">leading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">pack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">11</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">nods.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-0" stroke-width="2px" d="M62,377.0 62,352.0 188.0,352.0 188.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-1" stroke-width="2px" d="M212,377.0 212,252.0 1550.0,252.0 1550.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-2" stroke-width="2px" d="M212,377.0 212,352.0 338.0,352.0 338.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M338.0,379.0 L342.0,371.0 334.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-3" stroke-width="2px" d="M512,377.0 512,352.0 638.0,352.0 638.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,379.0 L508,371.0 516,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-4" stroke-width="2px" d="M662,377.0 662,302.0 1094.0,302.0 1094.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,379.0 L658,371.0 666,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9431fa03d1949eb8ed74ace92a9bf59-0-5" stroke-width="2px" d="M662,377.0 662,352.0 788.0,352.0 788.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9431fa03d1949eb8ed74
# The comic book villain origin story is up for best picture, best director and best actor for Joaquin Phoenix, plus eight other awards.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b3a46bbfeb354e29b345f7b0eb7a96f8-0" class="displacy" width="3500" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">comic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">book</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">villain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">origin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">story</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">picture,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">director</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">actor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">Joaquin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Phoenix,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">plus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">eight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">other</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">awards.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3a46bbfeb354e29b345f7b0eb7a96f8-0-0" stroke-width="2px" d="M62,452.0 62,402.0 338.0,402.0 338.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3a46bbfeb354e29b345f7b0eb7a96f8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,454.0 L58,446.0 66,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3a46bbfeb354e29b345f7b0eb7a96f8-0-1" stroke-width="2px" d="M212,452.0 212,427.0 335.0,427.0 335.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3a46bbfeb354e29b345f7b0eb7a96f8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,454.0 L208,446.0 216,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3a46bbfeb354e29b345f7b0eb7a96f8-0-2" stroke-width="2px" d="M362,452.0 362,352.0 944.0,352.0 944.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3a46bbfeb354e29b345f7b0eb7a96f8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,454.0 L358,446.0 366,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3a46bbfeb354e29b345f7b0eb7a96f8-0-3" stroke-width="2px" d="M512,452.0 512,402.0 788.0,402.0 788.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; lett
# The Irishman, 1917 and Once Upon a Time in Hollywood follow with 10 nominations each.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b500866c8874416b8bddcfc5d55eb7af-0" class="displacy" width="2300" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Irishman,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">1917</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Once</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Upon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Hollywood</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">follow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">10</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">nominations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">each.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b500866c8874416b8bddcfc5d55eb7af-0-0" stroke-width="2px" d="M62,377.0 62,352.0 188.0,352.0 188.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b500866c8874416b8bddcfc5d55eb7af-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b500866c8874416b8bddcfc5d55eb7af-0-1" stroke-width="2px" d="M212,377.0 212,252.0 1550.0,252.0 1550.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b500866c8874416b8bddcfc5d55eb7af-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b500866c8874416b8bddcfc5d55eb7af-0-2" stroke-width="2px" d="M212,377.0 212,352.0 338.0,352.0 338.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b500866c8874416b8bddcfc5d55eb7af-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M338.0,379.0 L342.0,371.0 334.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b500866c8874416b8bddcfc5d55eb7af-0-3" stroke-width="2px" d="M362,377.0 362,352.0 488.0,352.0 488.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b500866c8874416b8bddcfc5d55eb7af-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M488.0,379.0 L492.0,371.0 484.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b500866c8874416b8bddcfc5d55eb7af-0-4" stroke-width="2px" d="M662,377.0 662,277.0 1547.0,277.0 1547.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b500866c8874416b8bddcfc5d55eb7af-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,379.0 L658,371.0 666,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b500866c8874416b8bddcfc5d55eb7af-0-5" stroke-width="2px" d="M812,377.0 812,302.0 1544.0,302.0 1544.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b500866c8874416b8bddcfc5d55eb7af-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,379.0 L808,371.0 816,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b500866c8874416b8bddcfc5d55eb7af-0-6" stroke-width="2px" d="M962,377.0 962,352.0 1088.0,352.0 1088.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b500866c8874416b8bddcfc5d55eb7af-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy
# But who else has been nominated?
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5a2081b368d24c32a2dfe99f90674060-0" class="displacy" width="950" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: ivory; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">But</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">else</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">nominated?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5a2081b368d24c32a2dfe99f90674060-0-0" stroke-width="2px" d="M62,302.0 62,202.0 800.0,202.0 800.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5a2081b368d24c32a2dfe99f90674060-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5a2081b368d24c32a2dfe99f90674060-0-1" stroke-width="2px" d="M212,302.0 212,227.0 797.0,227.0 797.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5a2081b368d24c32a2dfe99f90674060-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5a2081b368d24c32a2dfe99f90674060-0-2" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5a2081b368d24c32a2dfe99f90674060-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M341.0,304.0 L345.0,296.0 337.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5a2081b368d24c32a2dfe99f90674060-0-3" stroke-width="2px" d="M512,302.0 512,252.0 794.0,252.0 794.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5a2081b368d24c32a2dfe99f90674060-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,304.0 L508,296.0 516,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5a2081b368d24c32a2dfe99f90674060-0-4" stroke-width="2px" d="M662,302.0 662,277.0 791.0,277.0 791.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5a2081b368d24c32a2dfe99f90674060-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
# </svg>

# %%
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Video The nominations for this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Academy Awards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  have been announced,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  leading the pack with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  nods. The comic book villain origin story is up for best picture, best director and best actor for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joaquin Phoenix
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , plus
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  other awards. The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irishman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Once Upon a Time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hollywood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  follow with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 nominations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  each. But who else has been nominated?</div>

# %% [markdown]
# Joker должен быть определён как Person. Также в данном контексте, Irishman, 1917, Once Upon a Time in Hollywood, это названия фильмов, и они должны определяться как WORK_OF_ART. Если контекст не учитывать, то категории соотнесены верно.

# %% [markdown]
# **Вывод:** Алгоритм поиска именнованных сущностей нужно улучшать, или расширять его словарь. А определение POS-тегов и синтаксических зависимостей работает довольно хорошо.
